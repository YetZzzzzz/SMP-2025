# %%
import json
import pandas as pd
import numpy as np
import os
import csv

# %%
from scipy import stats
from sklearn.metrics import f1_score, mean_absolute_error, mean_squared_error
src1 =json.load(open('./12090.json', encoding="utf-8"))
src2 =json.load(open('./two_bestlgbm_73599(60)_7311195(40).json', encoding="utf-8"))
# src3 = json.load(open('./75428.json', encoding="utf-8"))
src3 = json.load(open('./BEST6.json', encoding="utf-8"))
src4 = json.load(open('./BEST7.json', encoding="utf-8"))
r1 = [sample['popularity_score'] for sample in src1['result']]
r2 = [sample['popularity_score'] for sample in src2['result']]
r3 = [sample['popularity_score'] for sample in src3['result']]
r4 = [sample['popularity_score'] for sample in src4['result']]
r1 = np.array(r1)
r2 = np.array(r2)
r3 = np.array(r3)
r4 = np.array(r4)
mae12 = mean_absolute_error(r1, r2)
src12 = stats.spearmanr(r1, r2)[0]
print('mae12', mae12, 'src12',src12)
mae13 = mean_absolute_error(r1, r3)
src13 = stats.spearmanr(r1, r3)[0]
print('mae13', mae13, 'src13',src13)
mae14 = mean_absolute_error(r1, r4)
src14 = stats.spearmanr(r1, r4)[0]
print('mae14', mae14, 'src14',src14)
mae23 = mean_absolute_error(r2, r3)
src23 = stats.spearmanr(r2, r3)[0]
print('mae23', mae23, 'src23',src23)
mae24 = mean_absolute_error(r2, r4)
src24 = stats.spearmanr(r2, r4)[0]
print('mae24', mae24, 'src24',src24)
mae34 = mean_absolute_error(r4, r3)
src34 = stats.spearmanr(r4, r3)[0]
print('mae34', mae34, 'src34',src34)
# Out:
# mae12 0.5917197579097785 src12 0.9134201928966862
# mae13 0.7542719427846782 src13 0.8258179904386398
# mae14 0.683395714388557 src14 0.8474543635972973
# mae23 0.9445772115375242 src23 0.7765818161021346
# mae24 0.870484234210101 src24 0.8049059121144398
# mae34 0.5757826194339384 src34 0.8936084936214075

# %%
from scipy import stats
from sklearn.metrics import f1_score, mean_absolute_error, mean_squared_error
src1 =json.load(open('./0.737.json', encoding="utf-8"))
src2 = json.load(open('./BEST7.json', encoding="utf-8"))
r1 = [sample['popularity_score'] for sample in src1['result']]
r2 = [sample['popularity_score'] for sample in src2['result']]
r1 = np.array(r1)
r2 = np.array(r2)
mae12 = mean_absolute_error(r1, r2)
src12 = stats.spearmanr(r1, r2)[0]
print('mae12', mae12, 'src12',src12)
# Out:
# mae12 0.6901621560407795 src12 0.849702159820496

# %%
avg_all = 0.5 * r1 + 0.5 * r2

# %%
## 挑选几个系列的佼佼者,然后将之融合看效果
## 1.首先是catboost系列的,首选7058和704+的两个文件
src1 = json.load(open('./ori_results/704260.json', encoding="utf-8"))
src2 = json.load(open('./ori_results/705803.json', encoding="utf-8"))
## 2.然后挑linear_decay系列的,应该是725+左右的
src3 = json.load(open('./results/RESULTS318/725.json', encoding="utf-8"))
src4 = json.load(open('./results/RESULTS318/7196.json', encoding="utf-8"))
## 3.伪标签的来两个
src5 = json.load(open('./results/RESULTS318/72253.json', encoding="utf-8"))
src6 = json.load(open('./results/RESULTS318/72287.json', encoding="utf-8")) 
## 4.融合后最优方案来两个
src7 = json.load(open('./whatever/7356712.json', encoding="utf-8"))
src8 = json.load(open('./735836.json', encoding="utf-8"))
## label_norm的也来几个
src9 = json.load(open('./708893_n.json', encoding="utf-8"))
## autogluon的也来几个
src10 = json.load(open('./whatever/7077.json', encoding="utf-8"))
src11 = json.load(open('./MMP.json', encoding="utf-8"))
src12 = json.load(open('./auto_5f_Ensemble3.json', encoding="utf-8"))
src13 =json.load(open('./12090.json', encoding="utf-8"))
src14 = json.load(open('./auto_5f_Ensemble2.json', encoding="utf-8"))
src15 = json.load(open('./auto_5f_MMP1.json', encoding="utf-8")) 
## 龙哥的方案也可以添加几个
src16 = json.load(open('./results/RESULTS318/72348.json', encoding="utf-8"))
## 大杂烩,也不知道会出现啥
r1 = [sample['popularity_score'] for sample in src1['result']]
r2 = [sample['popularity_score'] for sample in src2['result']]
r3 = [sample['popularity_score'] for sample in src3['result']]
r4 = [sample['popularity_score'] for sample in src4['result']]
r5 = [sample['popularity_score'] for sample in src5['result']]
r6 = [sample['popularity_score'] for sample in src6['result']]
r7 = [sample['popularity_score'] for sample in src7['result']]
r8 = [sample['popularity_score'] for sample in src8['result']]
r9 = [sample['popularity_score'] for sample in src9['result']]
r10 = [sample['popularity_score'] for sample in src10['result']]
r11 = [sample['popularity_score'] for sample in src11['result']]
r12 = [sample['popularity_score'] for sample in src12['result']]
r13 = [sample['popularity_score'] for sample in src13['result']]
r14 = [sample['popularity_score'] for sample in src14['result']]
r15 = [sample['popularity_score'] for sample in src15['result']]
r16 = [sample['popularity_score'] for sample in src16['result']]

# %%
avg_all = 0.01*r1 + 0.01*r2 + 0.05*r3 + 0.06*r4 + 0.06* r5 + 0.06*r6 + 0.11*r7 + 0.11*r8 + 0.03*r9 + 0.01*r10 + 0.02*r11 + 0.02*r12 +0.3*r13+ 0.01*r14 + 0.03*r15 + 0.11*r16

# %%
r1 = np.array(r1)
r2 = np.array(r2)
r3 = np.array(r3)
r4 = np.array(r4)
r5 = np.array(r5)
r6 = np.array(r6)
r7 = np.array(r7)
r8 = np.array(r8)
r9 = np.array(r9)
r10 = np.array(r10)
r11 = np.array(r11)
r12 = np.array(r12)
r13 = np.array(r13)
r14 = np.array(r14)
r15 = np.array(r15)
r16 = np.array(r16)

# %%
all_r = []
all_r.append(r1)
all_r.append(r2)
all_r.append(r3)
all_r.append(r4)
all_r.append(r5)
all_r.append(r6)
all_r.append(r7)
all_r.append(r8)
all_r.append(r9)
all_r.append(r10)
all_r.append(r11)
all_r.append(r12)
all_r.append(r13)
all_r.append(r14)
all_r.append(r15)
all_r.append(r16)

# %%
from scipy import stats
from sklearn.metrics import f1_score, mean_absolute_error, mean_squared_error
src1 = json.load(open('./whatever/7077.json', encoding="utf-8"))
# src2 = json.load(open('./Autogluon_ENS.json', encoding="utf-8"))
src3 = json.load(open('./MMP.json', encoding="utf-8"))
src4 = json.load(open('./two_bestlgbm_73599(60)_7311195(40).json', encoding="utf-8"))
src5 = json.load(open('./auto_5f_Ensemble3.json', encoding="utf-8"))
src6 = json.load(open('./auto_5f_Ensemble2.json', encoding="utf-8"))
src7 = json.load(open('./auto_5f_MMP1.json', encoding="utf-8")) 
src8 = json.load(open('./whatever/norm129_n.json', encoding="utf-8")) # 0.7351526052915459
src9 = json.load(open('./whatever/train_aug_698822_n.json', encoding="utf-8")) # 0.7355541121348259
src10 = json.load(open('./whatever/train_aug_norm_697_n.json', encoding="utf-8")) # 0.7354378232793053, 0.7355538092451857,0.7341397963627748
src11 = json.load(open('./708893_n.json', encoding="utf-8"))
src12 = json.load(open('./whatever/7356712.json', encoding="utf-8"))
r1 = [sample['popularity_score'] for sample in src1['result']]
r2 = [sample['popularity_score'] for sample in src2['result']]
r3 = [sample['popularity_score'] for sample in src3['result']]
r4 = [sample['popularity_score'] for sample in src4['result']]
r5 = [sample['popularity_score'] for sample in src5['result']]
r6 = [sample['popularity_score'] for sample in src6['result']]
r7 = [sample['popularity_score'] for sample in src7['result']]
r8 = [sample['popularity_score'] for sample in src8['result']]
r9 = [sample['popularity_score'] for sample in src9['result']]
r10 = [sample['popularity_score'] for sample in src10['result']]
r11 = [sample['popularity_score'] for sample in src11['result']]
r12 = [sample['popularity_score'] for sample in src12['result']]
print('MEAN1', np.mean(r1),'STD1', np.std(r1))
print('MEAN2', np.mean(r2),'STD2', np.std(r2))
print('MEAN3', np.mean(r3),'STD3', np.std(r3))
print('MEAN4', np.mean(r4),'STD4', np.std(r4))
print('MEAN5', np.mean(r5),'STD4', np.std(r5))
print('MEAN6', np.mean(r6),'STD6', np.std(r6))
print('MEAN7', np.mean(r7),'STD7', np.std(r7))
print('MEAN8', np.mean(r8),'STD8', np.std(r8))
print('MEAN9', np.mean(r9),'STD9', np.std(r9))
print('MEAN10', np.mean(r10),'STD10', np.std(r10))
print('MEAN11', np.mean(r11),'STD11', np.std(r11))
print('MEAN12', np.mean(r12),'STD12', np.std(r12))
r1 = np.array(r1)
r2 = np.array(r2)
r3 = np.array(r3)
r4 = np.array(r4)
r5 = np.array(r5)
r6 = np.array(r6)
r7 = np.array(r7)
r8 = np.array(r8)
r9 = np.array(r9)
r10 = np.array(r10)
r11 = np.array(r11)
r12 = np.array(r12)
mae14 = mean_absolute_error(r1, r4)
src14 = stats.spearmanr(r1, r4)[0]
mae24 = mean_absolute_error(r2, r4)
src24 = stats.spearmanr(r2, r4)[0]
mae34 = mean_absolute_error(r3, r4)
src34 = stats.spearmanr(r3, r4)[0]
mae54 = mean_absolute_error(r5, r4)
src54 = stats.spearmanr(r5, r4)[0]
mae64 = mean_absolute_error(r6, r4)
src64 = stats.spearmanr(r6, r4)[0]
mae74 = mean_absolute_error(r7, r4)
src74 = stats.spearmanr(r7, r4)[0]
mae84 = mean_absolute_error(r8, r4)
src84 = stats.spearmanr(r8, r4)[0]
mae94 = mean_absolute_error(r9, r4)
src94 = stats.spearmanr(r9, r4)[0]
mae104 = mean_absolute_error(r10, r4)
src104 = stats.spearmanr(r10, r4)[0]
mae114 = mean_absolute_error(r11, r4)
src114 = stats.spearmanr(r11, r4)[0]
mae124 = mean_absolute_error(r12, r4)
src124 = stats.spearmanr(r12, r4)[0]
print('mae14', mae14, 'src14',src14)
print('mae24', mae24, 'src24',src24)
print('mae34', mae34, 'src34',src34)
print('mae54', mae54, 'src54',src54)
print('mae64', mae64, 'src64',src64)
print('mae74', mae74, 'src74',src74)
print('mae84', mae84, 'src84',src84)
print('mae94', mae94, 'src94',src94)
print('mae104', mae104, 'src104',src104)
print('mae114', mae114, 'src114',src114)
print('mae124', mae124, 'src124',src124)
# Out:
# MEAN1 5.389052722600939 STD1 1.6705644285226773
# MEAN2 6.23273192085546 STD2 1.7202164817098455
# MEAN3 5.353672427885547 STD3 1.8393343326390013
# MEAN4 5.256451600733189 STD4 1.995320742870022
# MEAN5 5.363993220216967 STD4 1.7782683941070776
# MEAN6 5.3683354367292235 STD6 1.7015243828813793
# MEAN7 5.358341176535738 STD7 1.8304225473733151
# MEAN8 5.2635202330256226 STD8 2.1140751122359536
# MEAN9 5.3598598097252745 STD9 1.7958772090978792
# MEAN10 5.359150882429491 STD10 1.7917507679870603
# MEAN11 5.296880459184521 STD11 1.760412405882343
# MEAN12 5.1027972283905845 STD12 1.74347294031046
# mae14 0.7011077818127989 src14 0.8858194220791155
# mae24 2.183605756672704 src24 0.07021266039629051
# mae34 0.9042201313445031 src34 0.7951301455934758
# mae54 0.6621141702246356 src54 0.8903130867095691
# mae64 0.6880783933163355 src64 0.8866735368380597
# mae74 0.9303332583964292 src74 0.7841594907298596
# mae84 0.7591820902536655 src84 0.8628096969003989
# ...

# %%
avg_all = 0.95*r4 + 0.05*r5
## 1, 2, 3, 5, 6  + 0.1*r2 + 0.1*r3
# avg_all = 0.6*r4 + 0.08*r3 + 0.07*r2 + 0.05*r1 + 0.05* r5 + 0.05*r6 + 0.05*r7 + 0.05*r8

avg_all
# Out:
# array([ 9.182045, 10.649645,  9.98747 , ...,  5.596175,  6.253655,
#         5.18447 ])

# %%
src1 = json.load(open('./results/results733/734486.json', encoding="utf-8"))
src2 = json.load(open('./results/results733/734538.json', encoding="utf-8"))
src3 = json.load(open('./results/results733/734582.json', encoding="utf-8")) 
src4 = json.load(open('./results/results733/734721.json', encoding="utf-8")) 
src5 = json.load(open('./results/results733/734753.json', encoding="utf-8"))
src6 = json.load(open('./results/results733/734800.json', encoding="utf-8")) 
src7 = json.load(open('./results/results733/734826.json', encoding="utf-8"))
src8 = json.load(open('./results/results733/734851.json', encoding="utf-8")) 
src9 = json.load(open('./results/results733/734852.json', encoding="utf-8")) 
src10 = json.load(open('./results/results733/734858.json', encoding="utf-8"))
src11 = json.load(open('./results/results733/734876.json', encoding="utf-8")) 
src12 = json.load(open('./results/results733/734877.json', encoding="utf-8"))
src13 = json.load(open('./auto_allfea_MMP.json', encoding="utf-8"))
r1 = [sample['popularity_score'] for sample in src1['result']]
r2 = [sample['popularity_score'] for sample in src2['result']]
r3 = [sample['popularity_score'] for sample in src3['result']]
r4 = [sample['popularity_score'] for sample in src4['result']]
r5 = [sample['popularity_score'] for sample in src5['result']]
r6 = [sample['popularity_score'] for sample in src6['result']]
r7 = [sample['popularity_score'] for sample in src7['result']]
r8 = [sample['popularity_score'] for sample in src8['result']]
r9 = [sample['popularity_score'] for sample in src9['result']]
r10 = [sample['popularity_score'] for sample in src10['result']]
r11 = [sample['popularity_score'] for sample in src11['result']]
r12 = [sample['popularity_score'] for sample in src12['result']]
r13 = [sample['popularity_score'] for sample in src13['result']]

print('MEAN1', np.mean(r1),'STD1', np.std(r1))
print('MEAN2', np.mean(r2),'STD2', np.std(r2))
print('MEAN3', np.mean(r3),'STD3', np.std(r3))
print('MEAN4', np.mean(r4),'STD4', np.std(r4))
print('MEAN5', np.mean(r5),'STD5', np.std(r5))
print('MEAN6', np.mean(r6),'STD6', np.std(r6))
print('MEAN7', np.mean(r7),'STD7', np.std(r7))
print('MEAN8', np.mean(r8),'STD8', np.std(r8))
print('MEAN9', np.mean(r9),'STD9', np.std(r9))
print('MEAN10', np.mean(r10),'STD10', np.std(r10))
print('MEAN11', np.mean(r11),'STD11', np.std(r11))
print('MEAN12', np.mean(r12),'STD12', np.std(r12))
print('MEAN13', np.mean(r13),'STD12', np.std(r13))
# Out:
# MEAN1 5.307073413599961 STD1 1.7214300413606969
# MEAN2 5.30731300013281 STD2 1.7211377248858508
# MEAN3 5.306390948471782 STD3 1.7171915488047351
# MEAN4 5.304460094915855 STD4 1.7313521311017186
# MEAN5 5.305908129797073 STD5 1.728231831542792
# MEAN6 5.305769688460736 STD6 1.7260832068407244
# MEAN7 5.303162238182291 STD7 1.736787804146283
# MEAN8 5.30533511341433 STD8 1.7277383410100235
# MEAN9 5.304031388275108 STD9 1.7330138931089558
# MEAN10 5.3052568899059755 STD10 1.7280417701198392
# MEAN11 5.304900538367922 STD11 1.7294452695813827
# MEAN12 5.304465963321512 STD12 1.7312038393504157
# MEAN13 5.344012292544621 STD12 1.788661196438126

# %%
src14 = json.load(open('./auto_ti_norm.json', encoding="utf-8"))
r14 = [sample['popularity_score'] for sample in src14['result']]
print('MEAN14', np.mean(r14),'STD12', np.std(r14))
# Out:
# MEAN14 5.356801122487969 STD12 1.7204150204580182

# %%
r1 = np.array(r1)
r2 = np.array(r2)
r3 = np.array(r3)
r4 = np.array(r4)
r5 = np.array(r5)
r6 = np.array(r6)
r7 = np.array(r7)

# %%
from scipy import stats
from sklearn.metrics import f1_score, mean_absolute_error, mean_squared_error
mae12 = mean_absolute_error(r1, r2)
src12 = stats.spearmanr(r1, r2)[0]
mae13 = mean_absolute_error(r1, r3)
src13 = stats.spearmanr(r1, r3)[0]
mae14 = mean_absolute_error(r1, r4)
src14 = stats.spearmanr(r1, r4)[0]
mae15 = mean_absolute_error(r1, r5)
src15 = stats.spearmanr(r1, r5)[0]
mae23 = mean_absolute_error(r2, r3)
src23 = stats.spearmanr(r2, r3)[0]
mae24 = mean_absolute_error(r2, r4)
src24 = stats.spearmanr(r2, r4)[0]
mae25 = mean_absolute_error(r2, r5)
src25 = stats.spearmanr(r2, r5)[0]
mae34 = mean_absolute_error(r3, r4)
src34 = stats.spearmanr(r3, r4)[0]
mae35 = mean_absolute_error(r3, r5)
src35 = stats.spearmanr(r3, r5)[0]
mae45 = mean_absolute_error(r4, r5)
src45 = stats.spearmanr(r4, r5)[0]
print('mae12', mae12, 'src12',src12)
print('mae13', mae13, 'src13',src13)
print('mae14', mae14, 'src14',src14)
print('mae15', mae15, 'src15',src15)
print('mae23', mae23, 'src23',src23)
print('mae24', mae24, 'src24',src24)
print('mae25', mae25, 'src25',src25)
print('mae34', mae34, 'src34',src34)
print('mae35', mae35, 'src35',src35)
print('mae45', mae45, 'src45',src45)
mae16 = mean_absolute_error(r1, r6)
src16 = stats.spearmanr(r1, r6)[0]
mae26 = mean_absolute_error(r2, r6)
src26 = stats.spearmanr(r2, r6)[0]
mae36 = mean_absolute_error(r3, r6)
src36 = stats.spearmanr(r3, r6)[0]
mae46 = mean_absolute_error(r4, r6)
src46 = stats.spearmanr(r4, r6)[0]
mae56 = mean_absolute_error(r5, r6)
src56 = stats.spearmanr(r5, r6)[0]
print('mae16', mae16, 'src16',src16)
print('mae26', mae26, 'src26',src26)
print('mae36', mae36, 'src36',src36)
print('mae46', mae46, 'src46',src46)
print('mae56', mae56, 'src56',src56)
# Out:
# mae12 0.002428069693830707 src12 0.9999513877167687
# mae13 0.12477852431872678 src13 0.9951410322191656
# mae14 0.3131683549210603 src14 0.9876270148603639
# mae15 0.2747604565264341 src15 0.9964535096512571
# mae23 0.1257803370208672 src23 0.99508237011459
# mae24 0.31407193658666654 src24 0.9875920167073513
# mae25 0.2762363425551954 src25 0.9964035615481934
# mae34 0.2833850083895871 src34 0.9915040015888811
# mae35 0.29156606652970135 src35 0.9928606366274756
# mae45 0.17579960073318895 src45 0.9894078357697201
# mae16 0.5727661957791794 src16 0.8962758224577527
# mae26 0.5726204979804809 src26 0.8961620098652631
# mae36 0.46804139361283864 src36 0.9319851218700974
# mae46 0.673575889490035 src46 0.9016008457988854
# mae56 0.7102243137428634 src56 0.8935113587910829

# %%
print('mae12', mae12, 'src12',src12)
print('mae13', mae13, 'src12',src13)
print('mae23', mae23, 'src12',src23)

# %%
# r1 = np.array(r1)
# r2 = np.array(r2)
# r3 = np.array(r3)
avg_all = 0.2*r25 + 0.05*r24 + 0.05*r13 +0.05* r3 +0.05* r5 + 0.6*r23
avg_all
# Out:
# array([ 8.844092, 10.968201, 10.141769, ...,  6.078068,  6.7469  ,
#         5.581026])

# %%
print('avg_MEAN', np.mean(avg_all),'avg_STD', np.std(avg_all))
# Out:
# avg_MEAN 5.142386730331541 avg_STD 1.7005604764456297

# %%
# src1 = json.load(open('./ori_results/69441.json', encoding="utf-8"))
src2 = json.load(open('./ori_results/69907.json', encoding="utf-8"))
src3 = json.load(open('./ori_results/692539.json', encoding="utf-8"))
# src4 = json.load(open('./ori_results/693475.json', encoding="utf-8"))
src5 = json.load(open('./ori_results/693503.json', encoding="utf-8"))
src6 = json.load(open('./ori_results/694092.json', encoding="utf-8"))
src7 = json.load(open('./ori_results/694946.json', encoding="utf-8"))
src8 = json.load(open('./ori_results/695030.json', encoding="utf-8"))
src9 = json.load(open('./ori_results/695259.json', encoding="utf-8"))
src10 = json.load(open('./ori_results/695599.json', encoding="utf-8"))
src11 = json.load(open('./ori_results/695690.json', encoding="utf-8"))
src12 = json.load(open('./ori_results/696710.json', encoding="utf-8"))
src13 = json.load(open('./ori_results/696756.json', encoding="utf-8"))
src14 = json.load(open('./ori_results/696916.json', encoding="utf-8"))
src15 = json.load(open('./ori_results/697099.json', encoding="utf-8"))
src16 = json.load(open('./ori_results/697538.json', encoding="utf-8"))
src17 = json.load(open('./ori_results/698068.json', encoding="utf-8"))
src18 = json.load(open('./ori_results/698273.json', encoding="utf-8"))
# src19 = json.load(open('./ori_results/704260.json', encoding="utf-8"))
# src20 = json.load(open('./ori_results/705803.json', encoding="utf-8"))


src21 = json.load(open('./results/RESULTS318/6932365.json', encoding="utf-8"))

# %%
src1 = json.load(open('./results/RESULTS318/725.json', encoding="utf-8"))
src2 = json.load(open('./results/RESULTS318/7213.json', encoding="utf-8"))
src3 = json.load(open('./results/RESULTS318/72086.json', encoding="utf-8"))
## src3 = json.load(open('./results/RESULTS318/72253.json', encoding="utf-8"))   ## pseudo
src4 = json.load(open('./results/RESULTS318/72266.json', encoding="utf-8"))
src5 = json.load(open('./results/RESULTS318/72287.json', encoding="utf-8"))   ## pseudo
src6 = json.load(open('./results/RESULTS318/72307.json', encoding="utf-8"))
src7 = json.load(open('./results/RESULTS318/72348.json', encoding="utf-8"))
src8 = json.load(open('./results/RESULTS318/72391.json', encoding="utf-8"))
src9 = json.load(open('./results/RESULTS318/727966.json', encoding="utf-8"))
src10 = json.load(open('./results/RESULTS318/72410.json', encoding="utf-8"))
src11 = json.load(open('./results/RESULTS318/72468.json', encoding="utf-8"))
src12 = json.load(open('./results/RESULTS318/72581.json', encoding="utf-8"))
src13 = json.load(open('./results/RESULTS318/719248.json', encoding="utf-8"))
src14 = json.load(open('./results/RESULTS318/723371.json', encoding="utf-8"))
src15 = json.load(open('./results/RESULTS318/723999.json', encoding="utf-8"))
## src15 = json.load(open('./results/RESULTS318/725298.json', encoding="utf-8"))
src16 = json.load(open('./results/RESULTS318/725887.json', encoding="utf-8"))
src17 = json.load(open('./results/RESULTS318/72281.json', encoding="utf-8"))
src18 = json.load(open('./results/RESULTS318/726836.json', encoding="utf-8"))
src19 = json.load(open('./results/RESULTS318/727999.json', encoding="utf-8"))
src20 = json.load(open('./results/RESULTS318/727352.json', encoding="utf-8"))
src21 = json.load(open('./results/RESULTS318/7196.json', encoding="utf-8"))
src22 = json.load(open('./results/RESULTS318/7196.json', encoding="utf-8"))
src23 = json.load(open('./results/RESULTS318/73123773.json', encoding="utf-8"))
src24 = json.load(open('./KFold_catboost12.json', encoding="utf-8"))
src25 = json.load(open('./KFold_catboost11.json', encoding="utf-8")) ## 0.6868964488152979
## src21 = json.load(open('./results/RESULTS318/728315.json', encoding="utf-8"))
## src22 = json.load(open('./results/RESULTS318/728245.json', encoding="utf-8"))

# %%
from scipy import stats
from sklearn.metrics import f1_score, mean_absolute_error, mean_squared_error
mae1 = mean_absolute_error(r1, r23)
src1 = stats.spearmanr(r1, r23)[0]
mae2 = mean_absolute_error(r2, r23)
src2 = stats.spearmanr(r2, r23)[0]
mae3 = mean_absolute_error(r3, r23)
src3 = stats.spearmanr(r3, r23)[0]
mae4 = mean_absolute_error(r4, r23)
src4 = stats.spearmanr(r4, r23)[0]
mae5 = mean_absolute_error(r5, r23)
src5 = stats.spearmanr(r5, r23)[0]
mae6 = mean_absolute_error(r6, r23)
src6 = stats.spearmanr(r6, r23)[0]
mae7 = mean_absolute_error(r7, r23)
src7 = stats.spearmanr(r7, r23)[0]
mae8 = mean_absolute_error(r8, r23)
src8 = stats.spearmanr(r8, r23)[0]
mae9 = mean_absolute_error(r9, r23)
src9 = stats.spearmanr(r9, r23)[0]
mae10 = mean_absolute_error(r10, r23)
src10 = stats.spearmanr(r10, r23)[0]
mae11 = mean_absolute_error(r11, r23)
src11 = stats.spearmanr(r11, r23)[0]
mae12 = mean_absolute_error(r12, r23)
src12 = stats.spearmanr(r12, r23)[0]
mae13 = mean_absolute_error(r13, r23)
src13 = stats.spearmanr(r13, r23)[0]
mae14 = mean_absolute_error(r14, r23)
src14 = stats.spearmanr(r14, r23)[0]
mae15 = mean_absolute_error(r15, r23)
src15 = stats.spearmanr(r15, r23)[0]
mae16 = mean_absolute_error(r16, r23)
src16 = stats.spearmanr(r16, r23)[0]
mae17 = mean_absolute_error(r17, r23)
src17 = stats.spearmanr(r17, r23)[0]
mae18 = mean_absolute_error(r18, r23)
src18 = stats.spearmanr(r18, r23)[0]
mae19 = mean_absolute_error(r19, r23)
src19 = stats.spearmanr(r19, r23)[0]
mae20 = mean_absolute_error(r20, r23)
src20 = stats.spearmanr(r20, r23)[0]
mae21 = mean_absolute_error(r21, r23)
src21 = stats.spearmanr(r21, r23)[0]
mae22 = mean_absolute_error(r22, r23)
src22 = stats.spearmanr(r22, r23)[0]
mae24 = mean_absolute_error(r24, r23)
src24 = stats.spearmanr(r24, r23)[0]
mae25 = mean_absolute_error(r25, r23)
src25 = stats.spearmanr(r25, r23)[0]


print('mae1', mae1, 'src1',src1)
print('mae2', mae2, 'src2',src2)
print('mae3', mae3, 'src3',src3)
print('mae4', mae4, 'src4',src4)
print('mae5', mae5, 'src5',src5)
print('mae6', mae6, 'src6',src6)
print('mae7', mae7, 'src7',src7)
print('mae8', mae8, 'src8',src8)
print('mae9', mae9, 'src9',src9)
print('mae10', mae10, 'src10',src10)
print('mae11', mae11, 'src11',src11)
print('mae12', mae12, 'src12',src12)
print('mae13', mae13, 'src13',src13)
print('mae14', mae14, 'src14',src14)
print('mae15', mae15, 'src15',src15)
print('mae16', mae16, 'src16',src16)
print('mae17', mae17, 'src17',src17)
print('mae18', mae18, 'src18',src18)
print('mae19', mae19, 'src19',src19)
print('mae20', mae20, 'src20',src20)
print('mae21', mae21, 'src21',src21)
print('mae22', mae22, 'src22',src22)
print('mae24', mae24, 'src24',src24)
print('mae25', mae25, 'src25',src25)
# Out:
# mae1 0.29156606652970135 src1 0.9928606366274756
# mae2 0.3295014751275051 src2 0.9912578850751482
# mae3 0.45766539602726763 src3 0.9795447651163808
# mae4 0.3107761606149041 src4 0.9899260777867354
# mae5 0.3414683818341907 src5 0.9840933845583691
# mae6 0.3102232190171355 src6 0.9901186236868185
# mae7 0.21599768536003233 src7 0.9899526017032197
# mae8 0.2884482477115533 src8 0.9920037977711088
# mae9 0.12707691407180155 src9 0.9949895823223222
# mae10 0.2582102395047097 src10 0.9896262978417525
# mae11 0.3055013351349256 src11 0.987225184070716
# mae12 0.3346973092407285 src12 0.9885148682633889
# mae13 0.3721001828542317 src13 0.9741760386204523
# mae14 0.2977587659831323 src14 0.9912007291105046
# mae15 0.19749862665507445 src15 0.9891436474897671
# mae16 0.2109331562013722 src16 0.9868984694909857
# mae17 0.33766169072789126 src17 0.988831753968615
# mae18 0.18670991073873275 src18 0.9949261349015118
# mae19 0.14792903814170189 src19 0.9952369670146038
# ...

# %%
src1 = json.load(open('./results/RESULTS318/727352.json', encoding="utf-8"))
src2 = json.load(open('./results/RESULTS318/72410.json', encoding="utf-8"))
src3 = json.load(open('./results/RESULTS318/723999.json', encoding="utf-8"))
src4 = json.load(open('./results/RESULTS318/725887.json', encoding="utf-8"))
src5 = json.load(open('./results/RESULTS318/726836.json', encoding="utf-8"))
src6 = json.load(open('./results/RESULTS318/727999.json', encoding="utf-8"))
src7 = json.load(open('./results/RESULTS318/727966.json', encoding="utf-8"))
src8 = json.load(open('./results/RESULTS318/728315.json', encoding="utf-8"))
src9 = json.load(open('./results/RESULTS318/728245.json', encoding="utf-8"))

# %%
r1 = [sample['popularity_score'] for sample in src1['result']]
r2 = [sample['popularity_score'] for sample in src2['result']]
r3 = [sample['popularity_score'] for sample in src3['result']]
r4 = [sample['popularity_score'] for sample in src4['result']]
r5 = [sample['popularity_score'] for sample in src5['result']]
r6 = [sample['popularity_score'] for sample in src6['result']]
r7 = [sample['popularity_score'] for sample in src7['result']]
r8 = [sample['popularity_score'] for sample in src8['result']]
r9 = [sample['popularity_score'] for sample in src9['result']]
r10 = [sample['popularity_score'] for sample in src10['result']]
r11 = [sample['popularity_score'] for sample in src11['result']]
r12 = [sample['popularity_score'] for sample in src12['result']]
r13 = [sample['popularity_score'] for sample in src13['result']]
r14 = [sample['popularity_score'] for sample in src14['result']]
r15 = [sample['popularity_score'] for sample in src15['result']]
r16 = [sample['popularity_score'] for sample in src16['result']]
r17 = [sample['popularity_score'] for sample in src17['result']]
r18 = [sample['popularity_score'] for sample in src18['result']]
r19 = [sample['popularity_score'] for sample in src19['result']]
r20 = [sample['popularity_score'] for sample in src20['result']]
r21 = [sample['popularity_score'] for sample in src21['result']]
r22 = [sample['popularity_score'] for sample in src22['result']]
r23 = [sample['popularity_score'] for sample in src23['result']]
r24 = [sample['popularity_score'] for sample in src24['result']]
r25 = [sample['popularity_score'] for sample in src25['result']]

# %%
print('MEAN1', np.mean(r1),'STD1', np.std(r1))
print('MEAN2', np.mean(r2),'STD2', np.std(r2))
print('MEAN3', np.mean(r3),'STD3', np.std(r3))
print('MEAN4', np.mean(r4),'STD4', np.std(r4))
print('MEAN5', np.mean(r5),'STD5', np.std(r5))
print('MEAN6', np.mean(r6),'STD6', np.std(r6))
print('MEAN7', np.mean(r7),'STD7', np.std(r7))
print('MEAN8', np.mean(r8),'STD8', np.std(r8))
print('MEAN9', np.mean(r9),'STD9', np.std(r9))
print('MEAN10', np.mean(r10),'STD10', np.std(r10))
print('MEAN11', np.mean(r11),'STD11', np.std(r11))
print('MEAN12', np.mean(r12),'STD12', np.std(r12))
print('MEAN13', np.mean(r13),'STD13', np.std(r13))
print('MEAN14', np.mean(r14),'STD14', np.std(r14))
print('MEAN15', np.mean(r15),'STD15', np.std(r15))
print('MEAN16', np.mean(r16),'STD16', np.std(r16))
print('MEAN17', np.mean(r17),'STD17', np.std(r17))
print('MEAN18', np.mean(r18),'STD18', np.std(r18))
print('MEAN19', np.mean(r19),'STD19', np.std(r19))
print('MEAN20', np.mean(r20),'STD20', np.std(r20))
print('MEAN21', np.mean(r21),'STD21', np.std(r21))
print('MEAN22', np.mean(r22),'STD22', np.std(r22))
# Out:
# MEAN1 5.09766742348309 STD1 2.038502032363505
# MEAN2 5.38770950155332 STD2 2.09763084008958
# MEAN3 5.129915158848385 STD3 2.0229965616159005
# MEAN4 5.070781071098288 STD4 2.0300814729790324
# MEAN5 5.5332212048886635 STD5 1.8102498394129443
# MEAN6 5.066109638112536 STD6 2.0311926433304617
# MEAN7 5.338910693816072 STD7 1.8218496662563064
# MEAN8 5.0957507113151435 STD8 2.0268299336683286
# MEAN9 5.257823336895907 STD9 1.7865183478963138
# MEAN10 5.265804455618254 STD10 1.5578340874091332
# MEAN11 5.45907945188032 STD11 1.6219031971947717
# MEAN12 5.508524452184892 STD12 1.6096557671716685
# MEAN13 5.081901911607534 STD13 2.0283492088600017
# MEAN14 5.261832935912417 STD14 1.769664874939377
# MEAN15 5.09766742348309 STD15 2.038502032363505
# MEAN16 5.242656741849918 STD16 1.729784687220634
# MEAN17 5.0264545001965875 STD17 2.0445245621914974
# MEAN18 5.264349428332867 STD18 1.9401172354650373
# MEAN19 5.247813068330679 STD19 1.8751931176072338
# ...

# %%
r1 = np.array(r1)
r2 = np.array(r2)
r3 = np.array(r3)
r4 = np.array(r4)
r5 = np.array(r5)
r6 = np.array(r6)
r7 = np.array(r7)
r8 = np.array(r8)
r9 = np.array(r9)
r10 = np.array(r10)
r11 = np.array(r11)
r12 = np.array(r12)
r13 = np.array(r13)
r14 = np.array(r14)
# r15 = np.array(r15)
# r16 = np.array(r16)
# r17 = np.array(r17)
# r18 = np.array(r18)
# r19 = np.array(r19)
# r20 = np.array(r20)
# r21 = np.array(r21)
# r22 = np.array(r22)
# r23 = np.array(r23)
# r24 = np.array(r24)
# r25 = np.array(r25)

# %%
r1 = pd.DataFrame(r1)
r1.columns = ['popularity1']
r2 = pd.DataFrame(r2)
r2.columns = ['popularity2']
r3 = pd.DataFrame(r3)
r3.columns = ['popularity3']
r4 = pd.DataFrame(r4)
r4.columns = ['popularity4']
r5 = pd.DataFrame(r5)
r5.columns = ['popularity5']
r6 = pd.DataFrame(r6)
r6.columns = ['popularity6']
r7 = pd.DataFrame(r7)
r7.columns = ['popularity7']
r8 = pd.DataFrame(r8)
r8.columns = ['popularity8']
r9 = pd.DataFrame(r9)
r9.columns = ['popularity9']
r10 = pd.DataFrame(r10)
r10.columns = ['popularity10']
r11 = pd.DataFrame(r11)
r11.columns = ['popularity11']
r12 = pd.DataFrame(r12)
r12.columns = ['popularity12']
r13 = pd.DataFrame(r13)
r13.columns = ['popularity13']
r14 = pd.DataFrame(r14)
r14.columns = ['popularity14']
r15 = pd.DataFrame(r15)
r15.columns = ['popularity15']
r16 = pd.DataFrame(r16)
r16.columns = ['popularity16']
r17 = pd.DataFrame(r17)
r17.columns = ['popularity17']
r18 = pd.DataFrame(r18)
r18.columns = ['popularity18']
r19 = pd.DataFrame(r19)
r19.columns = ['popularity19']
r20 = pd.DataFrame(r20)
r20.columns = ['popularity20']
r21 = pd.DataFrame(r21)
r21.columns = ['popularity21']
r22 = pd.DataFrame(r22)
r22.columns = ['popularity22']

# %%
avg_all = 0.03*r1+0.03*r2+0.04*r3+0.05*r4+0.05*r5+0.05*r6+0.05*r7+0.35*r8+0.35*r9
avg_all
# Out:
# array([ 9.16771365, 11.07286078, 10.16336563, ...,  6.02665994,
#         6.66369605,  5.28980176])

# %%
avg_all
# Out:
# array([ 9.16737007, 11.10949846, 10.23123632, ...,  6.02132297,
#         6.67652318,  5.26901648])

# %%
all_r = []
all_r.append(r1)
all_r.append(r2)
all_r.append(r3)
all_r.append(r4)
all_r.append(r5)
all_r.append(r6)
all_r.append(r7)
all_r.append(r8)
all_r.append(r9)
all_r.append(r10)
all_r.append(r11)
all_r.append(r12)
all_r.append(r13)
all_r.append(r14)
# all_r.append(r15)
# all_r.append(r16)
# all_r.append(r17)
# all_r.append(r18)
# all_r.append(r19)
# all_r.append(r20)
# all_r.append(r21)
# all_r.append(r22)
# all_r.append(r23)

# %%
avg_all_r = np.mean(all_r, axis=0)
avg_all_r = pd.DataFrame(avg_all_r)
avg_all_r.columns = ['norm2']

# %%
print('normed_mean:', np.mean(avg_all_r))
print('normed_std:', np.std(avg_all_r))
# Out:
# normed_mean: norm2    5.379743
# dtype: float64
# normed_std: norm2    1.784816
# dtype: float64
# E:\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
test_temporalspatial = json.load(open('./test_allmetadata_json/test_temporalspatial_information.json', encoding="utf-8"))
test_temporalspatial_pd = pd.DataFrame(test_temporalspatial)
test_temporalspatial_pd
# Out:
#           Postdate         Uid      Pid Longitude Geoaccuracy   Latitude
# 0       1456761600    8770@N36    50731                     0          0
# 1       1456912561   10082@N16    96454                     0          0
# 2       1457091227   10082@N16   172136                     0          0
# 3       1457077899   24607@N38   177707                     0          0
# 4       1457077818   24607@N38   177708                     0          0
# ...            ...         ...      ...       ...         ...        ...
# 180576  1465549430   49686@N77  1118324                     0          0
# 180577  1465542506   31147@N75  1118329                     0          0
# 180578  1465346127    5656@N26  1118336   4.88361          15  52.377734
# 180579  1465534658   28302@N36  1118349                     0          0
# 180580  1465465460  102192@N21  1118356                     0          0
#
# [180581 rows x 6 columns]

# %%
avg_all_r = pd.DataFrame(avg_all)
avg_all_r.columns = ['norm2']

# %%
test_score_tem = pd.concat([test_temporalspatial_pd, avg_all_r], axis = 1)
test_score_tem
# Out:
#           Postdate         Uid      Pid Longitude Geoaccuracy   Latitude  \
# 0       1456761600    8770@N36    50731                     0          0
# 1       1456912561   10082@N16    96454                     0          0
# 2       1457091227   10082@N16   172136                     0          0
# 3       1457077899   24607@N38   177707                     0          0
# 4       1457077818   24607@N38   177708                     0          0
# ...            ...         ...      ...       ...         ...        ...
# 180576  1465549430   49686@N77  1118324                     0          0
# 180577  1465542506   31147@N75  1118329                     0          0
# 180578  1465346127    5656@N26  1118336   4.88361          15  52.377734
# 180579  1465534658   28302@N36  1118349                     0          0
# 180580  1465465460  102192@N21  1118356                     0          0
#
#            norm2
# 0        8.96895
# 1       10.68020
# 2        9.81040
# 3        6.55130
# ...

# %%
result = pd.DataFrame()
result['post_id'] = test_score_tem['Pid'].apply(lambda x: 'post' + str(x))
result['popularity_score'] = test_score_tem['norm2'].round(decimals=4)

out_json = dict()
out_json["version"] = "BEST"
out_json["result"] = result.to_dict(orient='records')
out_json["external_data"] = {"used": "false", "details": "vilt_vqa, clip, bertweet,bert, sliding windows"}
f = open('BEST14.json', "w")
json.dump(out_json, f)
f.close()
